# %%
import matplotlib.pyplot as plt 
import numpy as np 

N_MOVES = 150
DNA_SIZE = N_MOVES*2
DIRECTION_BOUND = [0,1]
MATING_RATE = 0.8
MUTATE_RATE = 0.001
POP_SIZE = 100
N_GENERATIONS = 100
START_POINT = [0, 5]
GOAL_POINT = [10, 5]
OBSTACLE_LINE = np.array([[5,2], [5,8]])


class Individual(object):

    def __init__(self, DNA_size, DNA_bound, cross_rate, mutation_rate, pop_size):
        self.DNA_size = DNA_size
        DNA_bound[1]+=1
        self.DNA_bound = DNA_bound
        self.cross_rate = cross_rate
        self.mutation_rate = mutation_rate
        self.pop_size = pop_size

        self.pop = np.random.randint(*DNA_bound, size=(pop_size, DNA_size))

    def DNA2prodcuct(self, DNA, n_moves, start_point):
        pop=(DNA-0.5)/2
        pop[:, 0], pop[:, n_moves] =start_point[0], start_point[1]
        lines_x = np.cumsum(pop[:, :n_moves], axis=1)
        lines_y = np.cumsum(pop[:, n_moves:], axis=1) 
        return lines_x, lines_y

    def get_fitness(self, lines_x, lines_y, goal_point, obstacle_line):

        dist2goal = np.sqrt((goal_point[0] - lines_x[:, -1]) ** 2  + (goal_point[1]-lines_y[:, -1]) ** 2)
        fitness = np.power(1 / (dist2goal + 1), 2)
        points = (lines_x > obstacle_line[0, 0] - 0.5) & (lines_x < obstacle_line[1, 0] + 0.5)	
        y_values = np.where(points, lines_y, np.zeros_like(lines_y) - 100)
        bad_lines = ((y_values > obstacle_line[0, 1]) & (y_values < obstacle_line[1, 1])).max(axis=1)
        fitness[bad_lines] = 1e-6
        return fitness

    def select(self, fitness):
        index = np.random.choice(np.arange(self.pop_size), size= self.pop_size, replace=True, p= fitness/fitness.sum())
        return self.pop[index]

    def crossover(self, parent, pop):
        if(np.random.rand() < self.cross_rate):
            ind = np.random.randint(0, self.pop_size, size=1)
            cross_points = np.random.randint(0, 2, self.DNA_size).astype(bool)
            parent[cross_points] = pop[ind, cross_points]
        return parent

    def mutate(self, child):
        for point in range(self.DNA_size):
            if(np.random.rand() < self.mutation_rate):
                child[point] = np.random.randint(*self.DNA_bound)
        return child

    def evolve(self, fitness):
        pop = self.select(fitness)
        pop_copy=pop.copy()
        for parent in pop:
            child = self.crossover(parent, pop_copy)
            child = self.mutate(child)
            parent[:] = child
        self.pop = pop


class Line(object):
    def __init__(self, n_moves, goal_point, start_point, obstacle_line):
        self.n_moves = n_moves
        self.goal_point = goal_point
        self.start_point = start_point
        self.obstacle_line = obstacle_line

        plt.ion()

    def plotting(self, lines_x, lines_y):
        plt.cla()

        plt.scatter(*self.goal_point, s=200, c='r')
        plt.scatter(*self.start_point, s=100, c='b')
        plt.plot(self.obstacle_line[:, 0], self.obstacle_line[:, 1], lw=3, c='k')
        plt.plot(lines_x.T, lines_y.T, c='k')
        plt.xlim((-5, 15))
        plt.ylim((-5, 15))
        plt.pause(0.01)


individual = Individual(DNA_size=DNA_SIZE, DNA_bound=DIRECTION_BOUND, cross_rate=MATING_RATE, mutation_rate=MUTATE_RATE, pop_size=POP_SIZE)

env = Line(N_MOVES, GOAL_POINT, START_POINT, OBSTACLE_LINE)

for generation in range(N_GENERATIONS):
    lx, ly = individual.DNA2prodcuct(individual.pop, N_MOVES, START_POINT)
    fitness = individual.get_fitness(lx, ly, GOAL_POINT, OBSTACLE_LINE)
    individual.evolve(fitness)
    print('Generation :' , generation, 'and best fit:', fitness.max())
    env.plotting(lx, ly)

plt.ioff()
plt.show()
# Out:
# Generation : 0 and best fit: 0.025168882118136178
# Generation : 1 and best fit: 0.02163452585394277
# Generation : 2 and best fit: 0.021912590293173776
# Generation : 3 and best fit: 0.040765254903430435
# Generation : 4 and best fit: 0.040765254903430435
# Generation : 5 and best fit: 0.04823615991286152
# Generation : 6 and best fit: 0.04823615991286152
# Generation : 7 and best fit: 0.04543923753284298
# Generation : 8 and best fit: 0.040765254903430435
# Generation : 9 and best fit: 0.05511402362405642
# Generation : 10 and best fit: 0.05511402362405642
# Generation : 11 and best fit: 0.06744963495484023
# Generation : 12 and best fit: 0.06744963495484023
# Generation : 13 and best fit: 0.06744963495484023
# Generation : 14 and best fit: 0.10074386617673715
# Generation : 15 and best fit: 0.04977800468755311
# Generation : 16 and best fit: 0.06744963495484023
# Generation : 17 and best fit: 0.06744963495484023
# Generation : 18 and best fit: 0.06744963495484023
# Generation : 19 and best fit: 0.05511402362405642
# Generation : 20 and best fit: 0.05717892550882879
# Generation : 21 and best fit: 0.07829127678440297
# Generation : 22 and best fit: 0.10074386617673715
# Generation : 23 and best fit: 0.07829127678440297
# Generation : 24 and best fit: 0.06744963495484023
# Generation : 25 and best fit: 0.06744963495484023
# Generation : 26 and best fit: 0.08281746700084874
# Generation : 27 and best fit: 0.10074386617673715
# Generation : 28 and best fit: 0.0879629982643065
# Generation : 29 and best fit: 0.11858335739763023
# Generation : 30 and best fit: 0.11858335739763023
# Generation : 31 and best fit: 0.11858335739763023
# Generation : 32 and best fit: 0.16554986870309116
# Generation : 33 and best fit: 0.16554986870309116
# Generation : 34 and best fit: 0.13053920422250795
# Generation : 35 and best fit: 0.16554986870309116
# Generation : 36 and best fit: 0.19325502260123545
# Generation : 37 and best fit: 0.3119016527346512
# Generation : 38 and best fit: 0.3119016527346512
# Generation : 39 and best fit: 0.3119016527346512
# Generation : 40 and best fit: 0.545819714368591
# Generation : 41 and best fit: 0.545819714368591
# Generation : 42 and best fit: 0.545819714368591
# Generation : 43 and best fit: 0.545819714368591
# Generation : 44 and best fit: 0.545819714368591
# Generation : 45 and best fit: 0.545819714368591
# Generation : 46 and best fit: 0.545819714368591
# Generation : 47 and best fit: 0.545819714368591
# Generation : 48 and best fit: 0.545819714368591
# Generation : 49 and best fit: 0.545819714368591
# Generation : 50 and best fit: 0.545819714368591
# Generation : 51 and best fit: 0.545819714368591
# Generation : 52 and best fit: 0.545819714368591
# Generation : 53 and best fit: 0.545819714368591
# Generation : 54 and best fit: 0.545819714368591
# Generation : 55 and best fit: 0.545819714368591
# Generation : 56 and best fit: 0.545819714368591
# Generation : 57 and best fit: 0.545819714368591
# Generation : 58 and best fit: 0.545819714368591
# Generation : 59 and best fit: 0.545819714368591
# Generation : 60 and best fit: 0.545819714368591
# Generation : 61 and best fit: 0.545819714368591
# Generation : 62 and best fit: 0.545819714368591
# Generation : 63 and best fit: 0.545819714368591
# Generation : 64 and best fit: 0.545819714368591
# Generation : 65 and best fit: 0.545819714368591
# Generation : 66 and best fit: 0.545819714368591
# Generation : 67 and best fit: 0.545819714368591
# Generation : 68 and best fit: 0.545819714368591
# Generation : 69 and best fit: 0.545819714368591
# Generation : 70 and best fit: 0.545819714368591
# Generation : 71 and best fit: 0.545819714368591
# Generation : 72 and best fit: 0.545819714368591
# Generation : 73 and best fit: 0.545819714368591
# Generation : 74 and best fit: 0.545819714368591
# Generation : 75 and best fit: 0.545819714368591
# Generation : 76 and best fit: 0.545819714368591
# Generation : 77 and best fit: 0.545819714368591
# Generation : 78 and best fit: 0.545819714368591
# Generation : 79 and best fit: 0.545819714368591
# Generation : 80 and best fit: 0.545819714368591
# Generation : 81 and best fit: 0.545819714368591
# Generation : 82 and best fit: 0.545819714368591
# Generation : 83 and best fit: 0.545819714368591
# Generation : 84 and best fit: 0.545819714368591
# Generation : 85 and best fit: 0.545819714368591
# Generation : 86 and best fit: 0.545819714368591
# Generation : 87 and best fit: 0.545819714368591
# Generation : 88 and best fit: 0.545819714368591
# Generation : 89 and best fit: 0.545819714368591
# Generation : 90 and best fit: 0.545819714368591
# Generation : 91 and best fit: 0.545819714368591
# Generation : 92 and best fit: 0.545819714368591
# Generation : 93 and best fit: 0.545819714368591
# Generation : 94 and best fit: 0.545819714368591
# Generation : 95 and best fit: 0.545819714368591
# Generation : 96 and best fit: 0.545819714368591
# Generation : 97 and best fit: 0.545819714368591
# Generation : 98 and best fit: 0.545819714368591
# Generation : 99 and best fit: 0.545819714368591
